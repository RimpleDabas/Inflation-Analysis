# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Retail Canada.csv')
df.head(10)
# Out:
#   REF_DATE     GEO           DGUID                             Products  \
# 0  2017-01  Canada  2016A000011124      Beef stewing cuts, per kilogram
# 1  2017-01  Canada  2016A000011124    Beef striploin cuts, per kilogram
# 2  2017-01  Canada  2016A000011124  Beef top sirloin cuts, per kilogram
# 3  2017-01  Canada  2016A000011124          Beef rib cuts, per kilogram
# 4  2017-01  Canada  2016A000011124            Ground beef, per kilogram
# 5  2017-01  Canada  2016A000011124         Pork loin cuts, per kilogram
# 6  2017-01  Canada  2016A000011124          Pork rib cuts, per kilogram
# 7  2017-01  Canada  2016A000011124     Pork shoulder cuts, per kilogram
# 8  2017-01  Canada  2016A000011124          Whole chicken, per kilogram
# 9  2017-01  Canada  2016A000011124        Chicken breasts, per kilogram
#
#        UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  VALUE  \
# 0  Dollars      81         units          0  v1353834271       11.10  12.66
# 1  Dollars      81         units          0  v1353834272       11.20  21.94
# 2  Dollars      81         units          0  v1353834273       11.30  13.44
# 3  Dollars      81         units          0  v1353834311       11.41  20.17
# 4  Dollars      81         units          0  v1353834274       11.40   9.12
# 5  Dollars      81         units          0  v1353834275       11.50   7.34
# 6  Dollars      81         units          0  v1353834276       11.60   7.37
# 7  Dollars      81         units          0  v1353834312       11.42   4.76
# 8  Dollars      81         units          0  v1353834277       11.70   5.15
# 9  Dollars      81         units          0  v1353834278       11.80  11.38
#
#    STATUS  SYMBOL  TERMINATED  DECIMALS
# 0     NaN     NaN         NaN         2
# 1     NaN     NaN         NaN         2
# 2     NaN     NaN         NaN         2
# 3     NaN     NaN         NaN         2
# 4     NaN     NaN         NaN         2
# 5     NaN     NaN         NaN         2
# 6     NaN     NaN         NaN         2
# 7     NaN     NaN         NaN         2
# 8     NaN     NaN         NaN         2
# 9     NaN     NaN         NaN         2

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Products', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
df = df[['REF_DATE', 'GEO', 'Products', 'VALUE','UOM' ]]
df.head(10)
# Out:
#   REF_DATE     GEO                             Products  VALUE      UOM
# 0  2017-01  Canada      Beef stewing cuts, per kilogram  12.66  Dollars
# 1  2017-01  Canada    Beef striploin cuts, per kilogram  21.94  Dollars
# 2  2017-01  Canada  Beef top sirloin cuts, per kilogram  13.44  Dollars
# 3  2017-01  Canada          Beef rib cuts, per kilogram  20.17  Dollars
# 4  2017-01  Canada            Ground beef, per kilogram   9.12  Dollars
# 5  2017-01  Canada         Pork loin cuts, per kilogram   7.34  Dollars
# 6  2017-01  Canada          Pork rib cuts, per kilogram   7.37  Dollars
# 7  2017-01  Canada     Pork shoulder cuts, per kilogram   4.76  Dollars
# 8  2017-01  Canada          Whole chicken, per kilogram   5.15  Dollars
# 9  2017-01  Canada        Chicken breasts, per kilogram  11.38  Dollars

# %%
df.isnull().values.any()
# Out:
# False

# %%
df= df.rename(columns = {'GEO' : 'Location'})
df.dtypes
# Out:
# REF_DATE     object
# Location     object
# Products     object
# VALUE       float64
# UOM          object
# dtype: object

# %%
df['Products Name'] = df['Products'].astype('string').str.split(',').str[0]

df['Amount'] = df['Products'].astype('string').str.split(',').str[1]

df.sample(10)
# Out:
#       REF_DATE      Location                         Products  VALUE      UOM  \
# 31865  2019-03   Nova Scotia  Salad dressing, 475 millilitres   2.63  Dollars
# 14307  2017-12       Alberta                    Milk, 1 litre   2.18  Dollars
# 63450  2021-05        Quebec            Bananas, per kilogram   1.75  Dollars
# 13062  2017-11  Saskatchewan     Canned corn, 341 millilitres   1.07  Dollars
# 64697  2021-06        Quebec    Dry or fresh pasta, 500 grams   2.38  Dollars
# 23375  2018-08   Nova Scotia       Wheat flour, 2.5 kilograms   5.08  Dollars
# 9375   2017-08  Saskatchewan            Bananas, per kilogram   1.65  Dollars
# 74082  2022-02   Nova Scotia        Ground beef, per kilogram   9.71  Dollars
# 78419  2022-05       Alberta                   Broccoli, unit   3.10  Dollars
# 25784  2018-10   Nova Scotia   Frozen strawberries, 600 grams   4.40  Dollars
#
#              Products Name            Amount
# 31865       Salad dressing   475 millilitres
# 14307                 Milk           1 litre
# 63450              Bananas      per kilogram
# 13062          Canned corn   341 millilitres
# 64697   Dry or fresh pasta         500 grams
# 23375          Wheat flour     2.5 kilograms
# 9375               Bananas      per kilogram
# 74082          Ground beef      per kilogram
# 78419             Broccoli              unit
# 25784  Frozen strawberries         600 grams

# %%
df['Quantity'] = df['Amount'].astype('string').str.replace('per', '1')
df.sample(10)
# Out:
#        REF_DATE              Location                          Products  \
# 38703   2019-09                Canada                 Shrimp, 300 grams
# 16012   2018-02  Prince Edward Island          White sugar, 2 kilograms
# 34632   2019-05              Manitoba  Chicken drumsticks, per kilogram
# 33758   2019-04      British Columbia          Canned salmon, 213 grams
# 48323   2020-04      British Columbia           White rice, 2 kilograms
# 4594    2017-04          Saskatchewan      Mayonnaise, 890 millilitres
# 93362   2023-06  Prince Edward Island                    Cucumber, unit
# 91216   2023-04         New Brunswick   Salad dressing, 475 millilitres
# 101906  2024-01           Nova Scotia                    Milk, 4 litres
# 80953   2022-07      British Columbia        Frozen broccoli, 500 grams
#
#         VALUE      UOM       Products Name             Amount  \
# 38703    6.98  Dollars              Shrimp          300 grams
# 16012    2.37  Dollars         White sugar        2 kilograms
# 34632    6.31  Dollars  Chicken drumsticks       per kilogram
# 33758    4.23  Dollars       Canned salmon          213 grams
# 48323    8.48  Dollars          White rice        2 kilograms
# 4594     4.42  Dollars          Mayonnaise   890 millilitres
# 93362    1.67  Dollars            Cucumber               unit
# 91216    3.72  Dollars      Salad dressing    475 millilitres
# 101906   6.90  Dollars                Milk           4 litres
# 80953    3.70  Dollars     Frozen broccoli          500 grams
#
#                  Quantity
# 38703           300 grams
# 16012         2 kilograms
# 34632          1 kilogram
# 33758           213 grams
# 48323         2 kilograms
# 4594     890 millilitres
# 93362                unit
# 91216     475 millilitres
# 101906           4 litres
# 80953           500 grams

# %%
df['Year'] = df['REF_DATE'].astype('string').str.split('-').str[0]
df['Month'] = df['REF_DATE'].astype('string').str.split('-').str[1]
df.sample(10)
# Out:
#       REF_DATE              Location                       Products  VALUE  \
# 66757  2021-08  Prince Edward Island   Sweet potatoes, per kilogram   4.22
# 49358  2020-05               Alberta  Chicken breasts, per kilogram  12.60
# 14885  2018-01           Nova Scotia         Onions, 1.36 kilograms   3.08
# 95772  2023-08  Prince Edward Island         Potatoes, per kilogram   5.24
# 4096   2017-04         New Brunswick           Apples, per kilogram   4.64
# 65828  2021-07         New Brunswick             Almonds, 200 grams   5.83
# 56607  2020-11               Alberta      Ground beef, per kilogram  10.83
# 91855  2023-04      British Columbia               Ketchup, 1 litre   4.17
# 81258  2022-08  Prince Edward Island                    Limes, unit   1.02
# 66463  2021-07      British Columbia         Orange juice, 2 litres   3.98
#
#            UOM    Products Name           Amount         Quantity  Year Month
# 66757  Dollars   Sweet potatoes     per kilogram       1 kilogram  2021    08
# 49358  Dollars  Chicken breasts     per kilogram       1 kilogram  2020    05
# 14885  Dollars           Onions   1.36 kilograms   1.36 kilograms  2018    01
# 95772  Dollars         Potatoes     per kilogram       1 kilogram  2023    08
# 4096   Dollars           Apples     per kilogram       1 kilogram  2017    04
# 65828  Dollars          Almonds        200 grams        200 grams  2021    07
# 56607  Dollars      Ground beef     per kilogram       1 kilogram  2020    11
# 91855  Dollars          Ketchup          1 litre          1 litre  2023    04
# 81258  Dollars            Limes             unit             unit  2022    08
# 66463  Dollars     Orange juice         2 litres         2 litres  2021    07

# %%
df_check = df.loc[df['Products Name']=='Onions']
df_check
# Out:
#        REF_DATE                   Location                Products  VALUE  \
# 47      2017-01                     Canada    Onions, per kilogram   3.11
# 48      2017-01                     Canada  Onions, 1.36 kilograms   2.76
# 156     2017-01  Newfoundland and Labrador    Onions, per kilogram   5.51
# 157     2017-01  Newfoundland and Labrador  Onions, 1.36 kilograms   3.61
# 266     2017-01       Prince Edward Island    Onions, per kilogram   4.81
# ...         ...                        ...                     ...    ...
# 104901  2024-03               Saskatchewan  Onions, 1.36 kilograms   4.31
# 105010  2024-03                    Alberta    Onions, per kilogram   5.56
# 105011  2024-03                    Alberta  Onions, 1.36 kilograms   4.55
# 105120  2024-03           British Columbia    Onions, per kilogram   5.48
# 105121  2024-03           British Columbia  Onions, 1.36 kilograms   4.71
#
#             UOM Products Name           Amount         Quantity  Year Month
# 47      Dollars        Onions     per kilogram       1 kilogram  2017    01
# 48      Dollars        Onions   1.36 kilograms   1.36 kilograms  2017    01
# 156     Dollars        Onions     per kilogram       1 kilogram  2017    01
# 157     Dollars        Onions   1.36 kilograms   1.36 kilograms  2017    01
# 266     Dollars        Onions     per kilogram       1 kilogram  2017    01
# ...         ...           ...              ...              ...   ...   ...
# 104901  Dollars        Onions   1.36 kilograms   1.36 kilograms  2024    03
# 105010  Dollars        Onions     per kilogram       1 kilogram  2024    03
# 105011  Dollars        Onions   1.36 kilograms   1.36 kilograms  2024    03
# 105120  Dollars        Onions     per kilogram       1 kilogram  2024    03
# 105121  Dollars        Onions   1.36 kilograms   1.36 kilograms  2024    03
#
# [1914 rows x 10 columns]
